# %%
from bokeh.io import output_notebook
from bokeh.plotting import show
from pylabber.plotting.providers import Providers

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
p = Subject.objects.plot("sex", provider=Providers.BOKEH)
show(p)
# Out:
#   <div class="bk-root" id="7b2b1e88-8af3-47e2-8b7e-c3c2d5cd4184" data-root-id="1346"></div>

# %%
p = Subject.objects.plot("date_of_birth", plotter_kwargs={'by_sex': True});
